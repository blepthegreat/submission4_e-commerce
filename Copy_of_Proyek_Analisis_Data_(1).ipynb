# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** [Syahlevi Izza Mahendra]
# - **Email:** [slaxlevi@gmail.com]
# - **ID Dicoding:** [MS192D5Y0645]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# 1. Produk kategori apa yang paling banyak terjual?
# 2. Metode pembayaran mana yang paling sering digunakan oleh pelanggan?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import numpy as np
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\__init__.py:194
#     191         pass
#     192 del ta
# --> 194 from . import lib
#     195 from .lib import scimath as emath
#     196 from .lib._histograms_impl import (
#     197     histogram, histogram_bin_edges, histogramdd
#     198 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\lib\__init__.py:18
#      16 from . import npyio
#      17 from . import scimath
# ---> 18 from . import stride_tricks
#      20 # Private submodules
#      21 # load module names. See https://github.com/networkx/networkx/issues/5838
#      22 from . import _type_check_impl
#
# ...

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
import os
import glob
import pandas as pd
from google.colab import drive



folder_name = "E-Commerce Public Dataset"
folder_path = f"/content/drive/My Drive/E-Commerce Public Dataset"

# Cek apakah folder path benar
if not os.path.exists(folder_path):
    print(f"Folder tidak ditemukan: {folder_path}")
else:
    print(f"Folder ditemukan: {folder_path}")

# Cari file CSV
csv_files = glob.glob(os.path.join(folder_path, "*.csv"))
print(f"CSV files found: {csv_files}")

if not csv_files:
    print("Tidak ada file CSV yang ditemukan.")
else:
    # Membaca file CSV jika ada
    df_list = [pd.read_csv(file) for file in csv_files]
    combined_df = pd.concat(df_list, ignore_index=True)
    print(combined_df.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 4
#       2 import glob
#       3 import pandas as pd
# ----> 4 from google.colab import drive
#       8 folder_name = "E-Commerce Public Dataset"
#       9 folder_path = f"/content/drive/My Drive/E-Commerce Public Dataset"
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
file_path = "/content/drive/My Drive/E-Commerce Public Dataset/customers_dataset.csv"

customers_df = pd.read_csv(file_path)
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
file_path = "/content/drive/My Drive/E-Commerce Public Dataset/order_payments_dataset.csv"

order_payment_df = pd.read_csv(file_path)
order_payment_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
file_path = "/content/drive/My Drive/E-Commerce Public Dataset/order_items_dataset.csv"

order_items_dataset_df = pd.read_csv(file_path)
order_items_dataset_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
file_path = "/content/drive/My Drive/E-Commerce Public Dataset/products_dataset.csv"

products_dataset_df = pd.read_csv(file_path)
products_dataset_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# **Insight:**
# - Data yang dipersiapkan terdiri dari beberapa tabel transaksi dan pelanggan.
# - Untuk analisis ini, akan digunakan **order_items_dataset.csv** dan **order_payments_dataset.csv**.

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# :

# %%
order_items_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
order_items_dataset_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
print("Jumlah duplikasi:", order_items_dataset_df.duplicated().sum())
# Out:
# Jumlah duplikasi: 0

# %%
order_payment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
order_payment_df.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
print("Jumlah duplikasi:", order_payment_df.duplicated().sum())
# Out:
# Jumlah duplikasi: 0

# %% [markdown]
# **Insight:**
# - Tidak ada duplikasi pada dataset.
# - Beberapa kolom mungkin perlu diubah tipe datanya

# %% [markdown]
# ### Cleaning Data

# %%
order_items_dataset_df['shipping_limit_date'] = pd.to_datetime(order_items_dataset_df['shipping_limit_date'], errors='coerce')

# %%
order_items_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
order_payment_df['payment_value'] = order_payment_df['payment_value'].astype(float)

# %%
order_payment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %% [markdown]
# **Insight:**
# - Konversi shipping_limit_date ke datetime: Memudahkan analisis keterlambatan pengiriman dan kepatuhan terhadap tenggat waktu.
# - Konversi payment_value ke float: Memastikan data siap untuk analisis numerik seperti total pendapatan dan pola transaksi.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
    # Menghitung total penjualan per kategori produk
    product_sales = order_items_dataset_df.groupby("product_id")["order_item_id"].count().reset_index()
    product_sales = product_sales.merge(products_dataset_df, on="product_id", how="left")
    product_sales = product_sales.groupby("product_category_name")["order_item_id"].sum().sort_values(ascending=False)

    # Visualisasi Top 10 Kategori Produk Terlaris
    plt.figure(figsize=(12,6))
    sns.barplot(x=product_sales.index[:10], y=product_sales.values[:10], palette='coolwarm')
    plt.title("10 Produk Kategori Terlaris", fontsize=14)
    plt.xlabel("Kategori Produk", fontsize=12)
    plt.ylabel("Jumlah Terjual", fontsize=12)
    plt.xticks(rotation=45)
    plt.show()

    # Pie chart untuk menunjukkan distribusi kategori produk
    category_sales = product_sales.reset_index()
    plt.figure(figsize=(8, 8))
    plt.pie(category_sales['order_item_id'][:10], labels=category_sales['product_category_name'][:10], autopct='%1.1f%%', startangle=140, colors=sns.color_palette("coolwarm", 10))
    plt.title("Distribusi Penjualan Berdasarkan Kategori Produk Terlaris", fontsize=14)
    plt.show()
# Out:
# <ipython-input-9-9633afb10437>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=product_sales.index[:10], y=product_sales.values[:10], palette='coolwarm')

# %%
# Menghitung jumlah transaksi per metode pembayaran
payment_counts = order_payment_df["payment_type"].value_counts()

# Visualisasi jumlah transaksi per metode pembayaran
plt.figure(figsize=(8,6))
sns.barplot(x=payment_counts.index, y=payment_counts.values, palette='viridis')
plt.title("Metode Pembayaran yang Paling Banyak Digunakan", fontsize=14)
plt.xlabel("Metode Pembayaran", fontsize=12)
plt.ylabel("Jumlah Transaksi", fontsize=12)
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-7-070b1ece2167>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=payment_counts.index, y=payment_counts.values, palette='viridis')

# %% [markdown]
# **Insight:**
# - Insight 1:
#
# Dominasi Kategori Rumah & Lifestyle:
#
#
# Cama_mesa_banho mendominasi dengan 15.5% dari total penjualan
# Tiga kategori teratas (cama_mesa_banho, beleza_saude, dan esporte_lazer) secara total menyumbang 41.1% dari seluruh penjualan
# Kategori rumah tangga dan lifestyle (cama_mesa_banho, moveis_decoracao, utilidades_domesticas) secara total mencapai sekitar 36.8% dari keseluruhan penjualan
#
#
# Pola Distribusi yang Seimbang:
#
#
# Tidak ada kategori yang sangat mendominasi (tidak ada yang melebihi 20%)
# Distribusi cukup merata dengan mayoritas kategori memiliki porsi 6-15%
# Kategori teknologi (informatica_acessorios) memiliki porsi cukup signifikan (10.9%)
#
#
# Korelasi dengan Metode Pembayaran:
#
#
# Dominasi kartu kredit (75.000 transaksi) sangat relevan dengan kategori produk teratas
# Produk-produk rumah tangga dan lifestyle yang cenderung memiliki harga lebih tinggi cocok dengan preferensi pembayaran menggunakan kartu kredit
# Hal ini mengindikasikan konsumen lebih memilih cicilan untuk pembelian kategori-kategori utama

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %%
import datetime as dt


order_items_dataset_df['shipping_limit_date'] = pd.to_datetime(order_items_dataset_df['shipping_limit_date'])
latest_date = order_items_dataset_df['shipping_limit_date'].max()


rfm_products = order_items_dataset_df.merge(products_dataset_df, on="product_id", how="left")

rfm_products = rfm_products.groupby("product_category_name").agg({
    "shipping_limit_date": lambda x: (latest_date - x.max()).days,
    "order_id": "count",
    "price": "sum"
}).reset_index()

rfm_products.columns = ["product_category_name", "Recency", "Frequency", "Monetary"]

rfm_products.sort_values(by="Frequency", ascending=False).head(10)

plt.figure(figsize=(12,6))
sns.barplot(x=rfm_products.sort_values(by="Frequency", ascending=False)["product_category_name"][:10],
            y=rfm_products.sort_values(by="Frequency", ascending=False)["Frequency"][:10],
            palette="coolwarm")
plt.title("10 Produk Kategori Terlaris Berdasarkan Frequency (Jumlah Pembelian)", fontsize=14)
plt.xlabel("Kategori Produk", fontsize=12)
plt.ylabel("Jumlah Transaksi", fontsize=12)
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-37-3f6505f35691>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rfm_products.sort_values(by="Frequency", ascending=False)["product_category_name"][:10],

# %%
import pandas as pd
import numpy as np

# Load dataset
folder_path = "/content/drive/My Drive/E-Commerce Public Dataset/"
order_payment_df = pd.read_csv(folder_path + "order_payments_dataset.csv")
orders_df = pd.read_csv(folder_path + "orders_dataset.csv")

# Konversi tanggal transaksi ke format datetime
orders_df["order_purchase_timestamp"] = pd.to_datetime(orders_df["order_purchase_timestamp"])

# Gabungkan dataset pembayaran dengan informasi tanggal transaksi
order_payment_df = order_payment_df.merge(
    orders_df[["order_id", "order_purchase_timestamp"]],
    on="order_id",
    how="left"
)

# Menentukan tanggal referensi (hari terakhir dalam dataset)
latest_date = order_payment_df["order_purchase_timestamp"].max()

# Hitung RFM berdasarkan metode pembayaran
rfm_payment = order_payment_df.groupby("payment_type").agg({
    "order_purchase_timestamp": lambda x: (latest_date - x.max()).days,  # Recency (R)
    "order_id": "count",  # Frequency (F)
    "payment_value": "sum"  # Monetary (M)
}).reset_index()

# Ganti nama kolom agar lebih mudah dibaca
rfm_payment.columns = ["payment_type", "Recency", "Frequency", "Monetary"]

# Tampilkan hasil
print(rfm_payment.sort_values(by="Frequency", ascending=False))

import matplotlib.pyplot as plt
import seaborn as sns

# Urutkan berdasarkan Frequency agar lebih mudah dibaca
rfm_payment_sorted = rfm_payment.sort_values(by="Frequency", ascending=False)

# 🔹 Visualisasi Frequency, Monetary, dan Recency dengan Bar Chart
fig, axes = plt.subplots(3, 1, figsize=(10, 15))

# Frequency (Jumlah Transaksi per Metode Pembayaran)
sns.barplot(x=rfm_payment_sorted["Frequency"], y=rfm_payment_sorted["payment_type"], palette="Blues", ax=axes[0])
axes[0].set_title("🔹 Jumlah Transaksi per Metode Pembayaran", fontsize=14)
axes[0].set_xlabel("Frequency (Jumlah Transaksi)")
axes[0].set_ylabel("Metode Pembayaran")

# Monetary (Total Nilai Transaksi per Metode Pembayaran)
sns.barplot(x=rfm_payment_sorted["Monetary"], y=rfm_payment_sorted["payment_type"], palette="Greens", ax=axes[1])
axes[1].set_title("💰 Total Nilai Transaksi per Metode Pembayaran", fontsize=14)
axes[1].set_xlabel("Monetary (Total Nilai Transaksi)")
axes[1].set_ylabel("Metode Pembayaran")

# Recency (Seberapa Baru Transaksi Terakhir)
sns.barplot(x=rfm_payment_sorted["Recency"], y=rfm_payment_sorted["payment_type"], palette="Reds", ax=axes[2])
axes[2].set_title("🕒 Recency (Hari Sejak Transaksi Terakhir)", fontsize=14)
axes[2].set_xlabel("Recency (Hari Sejak Transaksi Terakhir)")
axes[2].set_ylabel("Metode Pembayaran")

plt.tight_layout()
plt.show()

# 🔹 Heatmap untuk Melihat Pola RFM
plt.figure(figsize=(10, 6))
sns.heatmap(rfm_payment_sorted.set_index("payment_type"), annot=True, fmt=".0f", cmap="coolwarm", linewidths=0.5)
plt.title("🔥 Heatmap RFM Metode Pembayaran", fontsize=14)
plt.show()
# Out:
#   payment_type  Recency  Frequency     Monetary
# 1  credit_card       49      76795  12542084.19
# 0       boleto       49      19784   2869361.27
# 4      voucher        0       5775    379436.87
# 2   debit_card       49       1529    217989.79
# 3  not_defined       44          3         0.00
# <ipython-input-16-c5b39e94c0ce>:45: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rfm_payment_sorted["Frequency"], y=rfm_payment_sorted["payment_type"], palette="Blues", ax=axes[0])
# <ipython-input-16-c5b39e94c0ce>:51: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rfm_payment_sorted["Monetary"], y=rfm_payment_sorted["payment_type"], palette="Greens", ax=axes[1])
# ...

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## Pertanyaan 1

# %% [markdown]
# Pertanyaan 1: Produk kategori apa yang paling banyak terjual?
# Berdasarkan data yang tersedia, kategori cama_mesa_banho (produk tempat tidur, meja, dan perlengkapan mandi) menjadi kategori yang paling banyak terjual dengan sekitar 11.000 transaksi. Posisi ini diikuti oleh kategori beleza_saude (kesehatan dan kecantikan) dengan sekitar 9.500 transaksi dan esporte_lazer (olahraga dan rekreasi) dengan 8.500 transaksi. Dominasi kategori cama_mesa_banho menunjukkan tingginya minat konsumen terhadap produk-produk rumah tangga. Hal ini mungkin mencerminkan fokus konsumen pada peningkatan kenyamanan rumah mereka, serta kebutuhan yang berkelanjutan akan produk-produk dalam kategori ini.

# %% [markdown]
# ## Pertanyaan 2

# %% [markdown]
# Pertanyaan 2 =
# Data RFM menunjukkan bahwa kartu kredit (credit_card) menjadi metode pembayaran yang paling sering digunakan oleh pelanggan, dengan 76.795 transaksi dan total nilai transaksi mencapai 12,5 juta. Dominasi kartu kredit ini sangat signifikan dibandingkan metode pembayaran lainnya. Di posisi kedua, boleto mencatatkan 19.784 transaksi dengan nilai total 2,8 juta, jauh di bawah kartu kredit. Metode pembayaran lain seperti voucher dan kartu debit menunjukkan penggunaan yang relatif kecil, dengan kartu debit hanya mencatatkan 1.529 transaksi. Dari segi kebaruan transaksi, hampir semua metode pembayaran aktif menunjukkan aktivitas dalam 49 hari terakhir, menandakan penggunaan yang konsisten untuk semua metode pembayaran yang tersedia, kecuali voucher yang menunjukkan tanda-tanda ketidakaktifan
